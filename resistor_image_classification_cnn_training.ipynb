# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam

train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    'dataset/',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    'dataset/',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

# Create sequential model
model = models.Sequential()

# Add custom layers
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
# Number of classes
model.add(layers.Dense(37, activation='softmax'))

# Model summary
model.summary()

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator
)

# Save the entire model as a `.keras` zip archive.
model.save('cnn.keras')
# Out:
# Found 2318 images belonging to 37 classes.
# Found 563 images belonging to 37 classes.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 52, 52, 64)        36928
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 52, 52, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 173056)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                11075648
# _________________________________________________________________
# dense_3 (Dense)              (None, 37)                2405
# =================================================================
# Total params: 11,134,373
# Trainable params: 11,134,373
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 73/73 [==============================] - 153s 2s/step - loss: 3.6136 - accuracy: 0.0343 - val_loss: 3.4994 - val_accuracy: 0.0693
# Epoch 2/10
# 73/73 [==============================] - 147s 2s/step - loss: 3.4642 - accuracy: 0.0683 - val_loss: 3.4720 - val_accuracy: 0.0888
# Epoch 3/10
# 73/73 [==============================] - 159s 2s/step - loss: 3.3613 - accuracy: 0.0903 - val_loss: 3.3524 - val_accuracy: 0.0906
# Epoch 4/10
# 73/73 [==============================] - 149s 2s/step - loss: 3.2252 - accuracy: 0.1157 - val_loss: 3.2556 - val_accuracy: 0.1474
# Epoch 5/10
# 73/73 [==============================] - 144s 2s/step - loss: 3.0875 - accuracy: 0.1591 - val_loss: 3.2120 - val_accuracy: 0.1226
# Epoch 6/10
# 73/73 [==============================] - 147s 2s/step - loss: 2.9408 - accuracy: 0.1951 - val_loss: 3.1329 - val_accuracy: 0.1208
# Epoch 7/10
# 73/73 [==============================] - 169s 2s/step - loss: 2.8021 - accuracy: 0.2325 - val_loss: 3.0930 - val_accuracy: 0.1723
# Epoch 8/10
# 73/73 [==============================] - 155s 2s/step - loss: 2.6610 - accuracy: 0.2557 - val_loss: 3.1347 - val_accuracy: 0.1350
# Epoch 9/10
# 73/73 [==============================] - 154s 2s/step - loss: 2.5725 - accuracy: 0.2861 - val_loss: 3.1712 - val_accuracy: 0.1368
# Epoch 10/10
# 73/73 [==============================] - 153s 2s/step - loss: 2.4398 - accuracy: 0.3016 - val_loss: 3.1699 - val_accuracy: 0.1243
